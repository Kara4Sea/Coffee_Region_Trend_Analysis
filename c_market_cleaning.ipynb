# %%
# import dependencies
import pathlib as path
import numpy as np
import pandas as pd

# %%
# export csv into dataframe
df_cmarket = pd.read_csv("Resources/coffee-prices-historical-chart-data.csv")
df_cmarket.head()
# Out:
#         date   value
# 0  8/20/1973  0.6735
# 1  8/21/1973  0.6710
# 2  8/22/1973  0.6580
# 3  8/23/1973  0.6675
# 4  8/24/1973  0.6660

# %%
#find dtypes
df_cmarket.dtypes
# Out:
# date       object
#  value    float64
# dtype: object

# %%
# convert date to datetime
df_cmarket['date'] = pd.to_datetime(df_cmarket['date'])
df_cmarket
# Out:
#             date   value
# 0     1973-08-20  0.6735
# 1     1973-08-21  0.6710
# 2     1973-08-22  0.6580
# 3     1973-08-23  0.6675
# 4     1973-08-24  0.6660
# ...          ...     ...
# 12499 2023-06-01     NaN
# 12500 2023-06-02     NaN
# 12501 2023-06-03     NaN
# 12502 2023-06-04     NaN
# 12503 2023-06-05     NaN
#
# [12504 rows x 2 columns]

# %%
#find dtypes
df_cmarket.dtypes
# Out:
# date      datetime64[ns]
#  value           float64
# dtype: object

# %%
#greater than the start date and smaller than the end date
mask = (df_cmarket['date'] > '2009-12-31') & (df_cmarket['date'] <= '2019-12-31')

# %%
# create df for 10 year time span
df_10_years = df_cmarket.loc[mask]
df_10_years
# Out:
#             date   value
# 9091  2010-01-04  1.4185
# 9092  2010-01-05  1.4100
# 9093  2010-01-06  1.4160
# 9094  2010-01-07  1.4190
# 9095  2010-01-08  1.4535
# ...          ...     ...
# 11610 2019-12-24  1.2940
# 11611 2019-12-26  1.2730
# 11612 2019-12-27  1.3250
# 11613 2019-12-30  1.3215
# 11614 2019-12-31  1.2970
#
# [2524 rows x 2 columns]

# %%
# find mean cmarket value by year in 10 year time span
df_avg_cmarket_year = df_10_years.groupby([df_10_years['date'].dt.strftime('%Y')]).mean()
df_avg_cmarket_year
# Out:
#          value
# date
# 2010  1.641608
# 2011  2.533816
# 2012  1.752797
# 2013  1.262510
# 2014  1.784025
# 2015  1.331508
# 2016  1.368253
# 2017  1.334556
# 2018  1.136044
# 2019  1.018240

# %%
# export to csv
file_path = "Resources/cmarket_value_avg_2010thru2019.csv"
df_avg_cmarket_year.to_csv(file_path, index=True)
